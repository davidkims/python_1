# %% [markdown]
# <a href="https://colab.research.google.com/github/davidkims/python_1/blob/main/TensorFlow_%EB%B0%8F_%EA%B0%81%EC%A2%85_%ED%85%8C%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tensorflow as tf

# %%
# 입력 데이터와 정답 데이터
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

# 모델 생성
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_dim=1))

# 모델 컴파일
model.compile(loss='mse', optimizer=tf.keras.optimizers.SGD(learning_rate=0.01))

# 모델 학습
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 781ms/step - loss: 31.1678
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 21.7579
# Epoch 3/100
# 1/1 [==============================] - 0s 12ms/step - loss: 15.2277
# Epoch 4/100
# 1/1 [==============================] - 0s 29ms/step - loss: 10.6958
# Epoch 5/100
# 1/1 [==============================] - 0s 22ms/step - loss: 7.5504
# Epoch 6/100
# 1/1 [==============================] - 0s 19ms/step - loss: 5.3672
# Epoch 7/100
# 1/1 [==============================] - 0s 68ms/step - loss: 3.8515
# Epoch 8/100
# 1/1 [==============================] - 0s 26ms/step - loss: 2.7990
# Epoch 9/100
# 1/1 [==============================] - 0s 15ms/step - loss: 2.0680
# Epoch 10/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5600
# Epoch 11/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.2067
# Epoch 12/100
# ...

# %%
# 모델 평가
loss = model.evaluate(x_train, y_train)
print(loss)

# 새로운 입력 데이터에 대한 예측
x_test = [5, 6, 7, 8]
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 132ms/step - loss: 0.2400
# 0.23995175957679749
# 1/1 [==============================] - 0s 89ms/step
# [[-3.160223 ]
#  [-3.7525403]
#  [-4.344857 ]
#  [-4.9371743]]

# %%
# !pip install cxflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 KB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 KB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 KB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 KB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.4/519.4 KB 46.7 MB/s eta 0:00:00
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26321 sha256=16b24b5e1341e260db8b0e48d516f779bf15d15b69124f24abe361ed558fa64d
#   Stored in directory: /root/.cache/pip/wheels/fa/17/1f/332799f975d1b2d7f9b3f33bbccf65031e794717d24432caee
# Successfully built typing
# ...

# %%
# !cxflow run
# Out:
# usage: cxflow
#        [-h]
#        [--version]
#        [--output_root OUTPUT_ROOT]
#        [--verbose]
#        {train,resume,predict,eval,dataset,gridsearch,ls,prune}
#        ...
# cxflow: error: argument {train,resume,predict,eval,dataset,gridsearch,ls,prune}: invalid choice: 'run' (choose from 'train', 'resume', 'predict', 'eval', 'dataset', 'gridsearch', 'ls', 'prune')

# %%
# !pip download cxintegrations
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement cxintegrations (from versions: none)
# ERROR: No matching distribution found for cxintegrations

# %%
# !curl -sSL https://github.com/github/codeql-cli-binaries/releases/latest/download/codeql.zip > codeql.zip && unzip codeql.zip -d codeql && rm codeql.zip
# Out:
# Archive:  codeql.zip
#    creating: codeql/codeql/
#   inflating: codeql/codeql/.codeqlmanifest.json
#   inflating: codeql/codeql/LICENSE.md
#    creating: codeql/codeql/Open-Source-Notices/
#   inflating: codeql/codeql/Open-Source-Notices/NOTICES
#   inflating: codeql/codeql/Open-Source-Notices/ant-notice.txt
#   inflating: codeql/codeql/Open-Source-Notices/apache-2.0.txt
#   inflating: codeql/codeql/Open-Source-Notices/bsd-2-clause.txt
#   inflating: codeql/codeql/Open-Source-Notices/bsd-3-clause.txt
#   inflating: codeql/codeql/Open-Source-Notices/cc-0.txt
#   inflating: codeql/codeql/Open-Source-Notices/cddl-gpl2.txt
#   inflating: codeql/codeql/Open-Source-Notices/commons-codec-notice.txt
#   inflating: codeql/codeql/Open-Source-Notices/commons-collections-notice.txt
#   inflating: codeql/codeql/Open-Source-Notices/commons-compress-notice.txt
#   inflating: codeql/codeql/Open-Source-Notices/commons-configuration-notice.txt
# ...

# %%
# !git clone https://github.com/davidkims/codeql
# Out:
# fatal: destination path 'codeql' already exists and is not an empty directory.

# %%
# !codeql query run my_query.ql --database=my_database
# Out:
# /bin/bash: codeql: command not found

# %%
# !pip install codacy-analysis-cli
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement codacy-analysis-cli (from versions: none)
# ERROR: No matching distribution found for codacy-analysis-cli

# %%
# !codeql database create my_database --language=python --source-root=my_project
# Out:
# /bin/bash: codeql: command not found
